# %% [markdown]
# #Identidas Diri
#
# Nama: Martza Zhugo Suryandra
# NIM: 250401020020]
# Kelas: Data Science IF401
# Dosen Pengampu : Syahid Abdullah, S.Si., M.Kom.

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama       = "Martza Zhugo Suryandra"     # String
angkatan   = 2025                         # Integer
ipk        = 3.82                         # Float
aktif      = True                         # Boolean
print(f"Nama    : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK     : {ipk}")
print(f"Aktif   : {aktif}")
# Out:
# Nama    : Martza Zhugo Suryandra
# Angkatan: 2025
# IPK     : 3.82
# Aktif   : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."
hasil = perkenalan("Martza ZHugo Suryandra", "Informatika", 2025)
print(hasil)
# Out:
# Hai! Saya Martza ZHugo Suryandra dari Informatika, angkatan 2025.

# %% [markdown]
# # Kesimpulan
#
# Pada pertemuan ini saya mempelajari dasar penggunaan Python dalam Data Science, termasuk variabel, tipe data, list, perulangan, dan fungsi sederhana.
#
# Temuan utama dari praktikum ini adalah bagaimana Python dapat digunakan untuk mengolah data sederhana secara terstruktur.
#
# Namun, masih terdapat keterbatasan dalam pemahaman logika pemrograman yang lebih kompleks, sehingga perlu latihan lebih lanjut pada bagian fungsi dan struktur data.
