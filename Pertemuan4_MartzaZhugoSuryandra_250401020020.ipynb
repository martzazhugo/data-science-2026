# %% [markdown]
# #Identidas Diri
#
# Nama: Martza Zhugo Suryandra
# NIM: 250401020020
# Kelas: Data Science IF401
# Dosen Pengampu : Syahid Abdullah, S.Si., M.Kom.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = sns.load_dataset('iris')
for col_name in df.select_dtypes(include='number').columns:
    col = df[col_name]
    print(f'\n=== {col_name} ===')
    print(f'  Mean     : {col.mean():.3f}')
    print(f'  Median   : {col.median():.3f}')
    print(f'  Std Dev  : {col.std():.3f}')
    print(f'  Skewness : {col.skew():.3f}')
    print(f'  Kurtosis : {col.kurt():.3f}')
# Out:
# === sepal_length ===
#   Mean     : 5.843
#   Median   : 5.800
#   Std Dev  : 0.828
#   Skewness : 0.315
#   Kurtosis : -0.552
#
# === sepal_width ===
#   Mean     : 3.057
#   Median   : 3.000
#   Std Dev  : 0.436
#   Skewness : 0.319
#   Kurtosis : 0.228
#
# === petal_length ===
#   Mean     : 3.758
#   Median   : 4.350
#   Std Dev  : 1.765
#   Skewness : -0.275
#   Kurtosis : -1.402
#
# === petal_width ===
#   Mean     : 1.199
#   Median   : 1.300
#   Std Dev  : 0.762
#   Skewness : -0.103
#   Kurtosis : -1.341

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Boxplot
sns.boxplot(
    data=df,
    x='species',
    y='petal_length',
    hue='species',
    palette='Set2',
    ax=axes[0],
    legend=False
)
axes[0].set_title('Boxplot Petal Length')

# Violin Plot
sns.violinplot(
    data=df,
    x='species',
    y='petal_length',
    hue='species',
    palette='Set2',
    inner='box',
    ax=axes[1],
    legend=False
)
axes[1].set_title('Violin Plot Petal Length')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Boxplot
sns.boxplot(data=df, x='species', y='petal_length', ax=axes[0])
axes[0].set_title('Boxplot Petal Length')

# Violin Plot
sns.violinplot(data=df, x='species', y='petal_length', inner='box', ax=axes[1])
axes[1].set_title('Violin Plot Petal Length')

plt.tight_layout()
plt.show()

# %%
# Menghitung matriks korelasi
corr = df.drop('species', axis=1).corr(method='pearson')
print(corr.round(3))

# Mencari pasangan dengan korelasi tertinggi
mask = np.triu(np.ones(corr.shape, dtype=bool))
corr_masked = corr.where(~mask)
max_pair = corr_masked.stack().idxmax()
print(f'Korelasi tertinggi: {max_pair} = {corr.loc[max_pair]:.3f}')
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length         1.000       -0.118         0.872        0.818
# sepal_width         -0.118        1.000        -0.428       -0.366
# petal_length         0.872       -0.428         1.000        0.963
# petal_width          0.818       -0.366         0.963        1.000
# Korelasi tertinggi: ('petal_width', 'petal_length') = 0.963

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Scatter Plot dengan garis regresi
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue='species', palette='Set2', ax=axes[0])
sns.regplot(data=df, x='petal_length', y='petal_width', scatter=False, color='gray', ax=axes[0])
axes[0].set_title('Scatter: Petal Length vs Petal Width')

# Heatmap Korelasi
sns.heatmap(corr, annot=True, fmt='.2f', cmap='RdBu_r', vmin=-1, vmax=1, square=True, ax=axes[1])
axes[1].set_title('Heatmap Korelasi')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Kesimpulan
#
# Pada praktikum ini saya mempelajari analisis statistik deskriptif dan visualisasi data menggunakan Python dengan library Pandas, NumPy, Matplotlib, dan Seaborn. Dataset yang digunakan adalah dataset Iris.
#
# Dari hasil praktikum, dilakukan perhitungan statistik seperti mean, median, standar deviasi, serta analisis skewness untuk memahami distribusi data. Selain itu, dilakukan visualisasi menggunakan histogram, boxplot, violin plot, dan scatter plot untuk melihat distribusi data serta hubungan antar variabel.
#
# Hasil analisis menunjukkan adanya perbedaan karakteristik antar spesies bunga Iris, serta terdapat korelasi yang kuat antara beberapa variabel seperti petal length dan petal width.
#
# Namun, analisis ini masih bersifat eksploratif dan belum mencakup pemodelan lanjutan atau prediksi menggunakan algoritma machine learning.
